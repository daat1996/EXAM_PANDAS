# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
font_path=r'C:/Windows/Fonts/gulim.ttc'

# %%
myFont=fm.FontProperties(fname=font_path).get_name()
mpl.rc('font', family=myFont)

# %%
file = '../DATA/pokedex-korean.json'

# %%
DP0=pd.read_json(file)
DP0
# Out:
#       id  num  name                                               img  \
# 0      1    1  이상해씨  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2    2  이상해풀  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3  이상해꽃  http://www.serebii.net/pokemongo/pokemon/003.png
# 3      4    4   파이리  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5    5   리자드  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...   ...                                               ...
# 146  147  147    미뇽  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148    신뇽  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   망나뇽  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150    뮤츠  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151     뮤  http://www.serebii.net/pokemongo/pokemon/151.png
#
#          type  height    weight           candy    egg  \
# 0       풀 / 독  0.71 m    6.9 kg      25 이상해씨 캔디   2 km
# ...

# %%
DP1=DP0.drop(['img','id'],axis=1).set_index('num')
DP1
# Out:
#      name      type  height    weight           candy    egg  \
# num
# 1    이상해씨     풀 / 독  0.71 m    6.9 kg      25 이상해씨 캔디   2 km
# 2    이상해풀     풀 / 독  0.99 m   13.0 kg     100 이상해씨 캔디   None
# 3    이상해꽃     풀 / 독  2.01 m  100.0 kg              없음   None
# 4     파이리        불꽃  0.61 m    8.5 kg       25 파이리 캔디   2 km
# 5     리자드        불꽃  1.09 m   19.0 kg      100 파이리 캔디   None
# ..    ...       ...     ...       ...             ...    ...
# 147    미뇽       드래곤  1.80 m    3.3 kg        25 미뇽 캔디  10 km
# 148    신뇽       드래곤  3.99 m   16.5 kg  100 Dratini 캔디   None
# 149   망나뇽  드래곤 / 비행  2.21 m  210.0 kg              없음   None
# 150    뮤츠       에스퍼  2.01 m  122.0 kg              없음   None
# 151     뮤       에스퍼  0.41 m    4.0 kg              없음   None
#
#                     multipliers          weaknesses  \
# num
# 1                          1.58   [불꽃, 얼음, 비행, 에스퍼]
# 2                    [1.2, 1.6]   [불꽃, 얼음, 비행, 에스퍼]
# 3                          None   [불꽃, 얼음, 비행, 에스퍼]
# ...

# %%
DP1['multipliers']
# Out:
# num
# 1                            1.58
# 2                      [1.2, 1.6]
# 3                            None
# 4                            1.65
# 5                            1.79
#                   ...
# 147    [1.83, 1.8399999999999999]
# 148                          2.05
# 149                          None
# 150                          None
# 151                          None
# Name: multipliers, Length: 151, dtype: object

# %%
DP1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            151 non-null    object
#  1   type            151 non-null    object
#  2   height          151 non-null    object
#  3   weight          151 non-null    object
#  4   candy           151 non-null    object
#  5   egg             73 non-null     object
#  6   multipliers     70 non-null     object
#  7   weaknesses      151 non-null    object
#  8   next_evolution  70 non-null     object
#  9   prev_evolution  71 non-null     object
# dtypes: object(10)
# memory usage: 13.0+ KB

# %%
htSR=DP1['height'].str[:-2]
htSR
# Out:
# num
# 1      0.71
# 2      0.99
# 3      2.01
# 4      0.61
# 5      1.09
#        ...
# 147    1.80
# 148    3.99
# 149    2.21
# 150    2.01
# 151    0.41
# Name: height, Length: 151, dtype: object

# %%
type(htSR)
# Out:
# pandas.core.series.Series

# %%
wtSR=DP1['weight'].str[:-3]
wtSR
# Out:
# num
# 1        6.9
# 2       13.0
# 3      100.0
# 4        8.5
# 5       19.0
#        ...
# 147      3.3
# 148     16.5
# 149    210.0
# 150    122.0
# 151      4.0
# Name: weight, Length: 151, dtype: object

# %%
htSR=htSR.astype('float')
wtSR=wtSR.astype('float')

# %%
print(htSR,wtSR,sep='\n\n')
# Out:
# num
# 1      0.71
# 2      0.99
# 3      2.01
# 4      0.61
# 5      1.09
#        ...
# 147    1.80
# 148    3.99
# 149    2.21
# 150    2.01
# 151    0.41
# Name: height, Length: 151, dtype: float64
#
# num
# 1        6.9
# 2       13.0
# 3      100.0
# 4        8.5
# 5       19.0
#        ...
# 147      3.3
# 148     16.5
# 149    210.0
# 150    122.0
# 151      4.0
# Name: weight, Length: 151, dtype: float64

# %%
BmSR=round((wtSR/htSR**2),2)
BmSR
# Out:
# num
# 1      13.69
# 2      13.26
# 3      24.75
# 4      22.84
# 5      15.99
#        ...
# 147     1.02
# 148     1.04
# 149    43.00
# 150    30.20
# 151    23.80
# Length: 151, dtype: float64

# %%
BmSR.describe()
# Out:
# count    151.000000
# mean      32.716689
# std       23.071774
# min        0.040000
# 25%       20.630000
# 50%       30.100000
# 75%       38.270000
# max      153.060000
# dtype: float64

# %%
DP1['BMI']=BmSR
DP1
# Out:
#      name      type  height    weight           candy    egg  \
# num
# 1    이상해씨     풀 / 독  0.71 m    6.9 kg      25 이상해씨 캔디   2 km
# 2    이상해풀     풀 / 독  0.99 m   13.0 kg     100 이상해씨 캔디   None
# 3    이상해꽃     풀 / 독  2.01 m  100.0 kg              없음   None
# 4     파이리        불꽃  0.61 m    8.5 kg       25 파이리 캔디   2 km
# 5     리자드        불꽃  1.09 m   19.0 kg      100 파이리 캔디   None
# ..    ...       ...     ...       ...             ...    ...
# 147    미뇽       드래곤  1.80 m    3.3 kg        25 미뇽 캔디  10 km
# 148    신뇽       드래곤  3.99 m   16.5 kg  100 Dratini 캔디   None
# 149   망나뇽  드래곤 / 비행  2.21 m  210.0 kg              없음   None
# 150    뮤츠       에스퍼  2.01 m  122.0 kg              없음   None
# 151     뮤       에스퍼  0.41 m    4.0 kg              없음   None
#
#                     multipliers          weaknesses  \
# num
# 1                          1.58   [불꽃, 얼음, 비행, 에스퍼]
# 2                    [1.2, 1.6]   [불꽃, 얼음, 비행, 에스퍼]
# 3                          None   [불꽃, 얼음, 비행, 에스퍼]
# ...

# %%
DP2=DP1.drop(columns=DP1.columns[4:10])
DP2
# Out:
#      name      type  height    weight    BMI
# num
# 1    이상해씨     풀 / 독  0.71 m    6.9 kg  13.69
# 2    이상해풀     풀 / 독  0.99 m   13.0 kg  13.26
# 3    이상해꽃     풀 / 독  2.01 m  100.0 kg  24.75
# 4     파이리        불꽃  0.61 m    8.5 kg  22.84
# 5     리자드        불꽃  1.09 m   19.0 kg  15.99
# ..    ...       ...     ...       ...    ...
# 147    미뇽       드래곤  1.80 m    3.3 kg   1.02
# 148    신뇽       드래곤  3.99 m   16.5 kg   1.04
# 149   망나뇽  드래곤 / 비행  2.21 m  210.0 kg  43.00
# 150    뮤츠       에스퍼  2.01 m  122.0 kg  30.20
# 151     뮤       에스퍼  0.41 m    4.0 kg  23.80
#
# [151 rows x 5 columns]

# %%
DP2.sort_values('BMI')
# Out:
#      name     type  height    weight     BMI
# num
# 93   고우스트  고스트 / 독  1.60 m    0.1 kg    0.04
# 92    고오스  고스트 / 독  1.30 m    0.1 kg    0.06
# 147    미뇽      드래곤  1.80 m    3.3 kg    1.02
# 148    신뇽      드래곤  3.99 m   16.5 kg    1.04
# 23     아보        독  2.01 m    6.9 kg    1.71
# ..    ...      ...     ...       ...     ...
# 75    데구리   바위 / 땅  0.99 m  105.0 kg  107.13
# 56     망키       격투  0.51 m   28.0 kg  107.65
# 111   뿔카노   땅 / 바위  0.99 m  115.0 kg  117.33
# 74    꼬마돌   바위 / 땅  0.41 m   20.0 kg  118.98
# 76    딱구리   바위 / 땅  1.40 m  300.0 kg  153.06
#
# [151 rows x 5 columns]

# %%
DP2[DP2.name=='망나뇽']
# Out:
#     name      type  height    weight   BMI
# num
# 149  망나뇽  드래곤 / 비행  2.21 m  210.0 kg  43.0

# %%
nonSR=DP1['prev_evolution'].isna() & DP1['next_evolution'].isna()
nonSR                    # 진화 없는 개체
# Out:
# num
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 147    False
# 148    False
# 149    False
# 150     True
# 151     True
# Length: 151, dtype: bool

# %%
DPnon_ev=DP2[nonSR]
DPnon_ev
# Out:
#      name      type  height    weight     BMI
# num
# 83    파오리   노말 / 비행  0.79 m   15.0 kg   24.03
# 95    롱스톤    바위 / 땅  8.79 m  210.0 kg    2.72
# 106  시라소몬        격투  1.50 m   49.8 kg   22.13
# 107   홍수몬        격투  1.40 m   50.2 kg   25.61
# 108   내루미        노말  1.19 m   65.5 kg   46.25
# 113    럭키        노말  1.09 m   34.6 kg   29.12
# 114   덩쿠리         풀  0.99 m   35.0 kg   35.71
# 115    캥카        노말  2.21 m   80.0 kg   16.38
# 122   마임맨       에스퍼  1.30 m   54.5 kg   32.25
# 123   스라크   벌레 / 비행  1.50 m   56.0 kg   24.89
# 124   루주라  얼음 / 에스퍼  1.40 m   40.6 kg   20.71
# 125   에레브        전기  1.09 m   30.0 kg   25.25
# 126   마그마        불꽃  1.30 m   44.5 kg   26.33
# 127  쁘사이저        벌레  1.50 m   55.0 kg   24.44
# 128  켄타로스        노말  1.40 m   88.4 kg   45.10
# 131  라프라스    물 / 얼음  2.49 m  220.0 kg   35.48
# 132   메타몽        노말  0.30 m    4.0 kg   44.44
# 137   폴리곤        노말  0.79 m   36.5 kg   58.48
# 142   프테라   바위 / 비행  1.80 m   59.0 kg   18.21
# ...

# %%
DPpre_ev=DP2[DP1['prev_evolution'].isna()]
DPpre_ev
# Out:
#      name     type  height    weight    BMI
# num
# 1    이상해씨    풀 / 독  0.71 m    6.9 kg  13.69
# 4     파이리       불꽃  0.61 m    8.5 kg  22.84
# 7     꼬부기        물  0.51 m    9.0 kg  34.60
# 10    캐터피       벌레  0.30 m    2.9 kg  32.22
# 13    뿔충이   벌레 / 독  0.30 m    3.2 kg  35.56
# ..    ...      ...     ...       ...    ...
# 146   파이어  불꽃 / 비행  2.01 m   60.0 kg  14.85
# 147    미뇽      드래곤  1.80 m    3.3 kg   1.02
# 148    신뇽      드래곤  3.99 m   16.5 kg   1.04
# 150    뮤츠      에스퍼  2.01 m  122.0 kg  30.20
# 151     뮤      에스퍼  0.41 m    4.0 kg  23.80
#
# [80 rows x 5 columns]

# %%
DPnext_ev=DP2[DP1['next_evolution'].isna()]
DPnext_ev
# Out:
#      name      type  height    weight    BMI
# num
# 3    이상해꽃     풀 / 독  2.01 m  100.0 kg  24.75
# 6     리자몽   불꽃 / 비행  1.70 m   90.5 kg  31.31
# 9     거북왕         물  1.60 m   85.5 kg  33.40
# 12    버터플   벌레 / 비행  1.09 m   32.0 kg  26.93
# 15    독침붕    벌레 / 독  0.99 m   29.5 kg  30.10
# ..    ...       ...     ...       ...    ...
# 145    썬더   전기 / 비행  1.60 m   52.6 kg  20.55
# 146   파이어   불꽃 / 비행  2.01 m   60.0 kg  14.85
# 149   망나뇽  드래곤 / 비행  2.21 m  210.0 kg  43.00
# 150    뮤츠       에스퍼  2.01 m  122.0 kg  30.20
# 151     뮤       에스퍼  0.41 m    4.0 kg  23.80
#
# [81 rows x 5 columns]

# %%
DPgrass=DP2[DP2['type'].str.contains('풀')]
DPgrass
# Out:
#       name     type  height    weight    BMI
# num
# 1     이상해씨    풀 / 독  0.71 m    6.9 kg  13.69
# 2     이상해풀    풀 / 독  0.99 m   13.0 kg  13.26
# 3     이상해꽃    풀 / 독  2.01 m  100.0 kg  24.75
# 43     뚜벅쵸    풀 / 독  0.51 m    5.4 kg  20.76
# 44     냄새꼬    풀 / 독  0.79 m    8.6 kg  13.78
# 45   라플레시아    풀 / 독  1.19 m   18.6 kg  13.13
# 46     파라스   벌레 / 풀  0.30 m    5.4 kg  60.00
# 47    파라섹트   벌레 / 풀  0.99 m   29.5 kg  30.10
# 69     모다피    풀 / 독  0.71 m    4.0 kg   7.93
# 70     우츠동    풀 / 독  0.99 m    6.4 kg   6.53
# 71    우츠보트    풀 / 독  1.70 m   15.5 kg   5.36
# 102    아라리  풀 / 에스퍼  0.41 m    2.5 kg  14.87
# 103     나시  풀 / 에스퍼  2.01 m  120.0 kg  29.70
# 114    덩쿠리        풀  0.99 m   35.0 kg  35.71

# %%
DPpoison=DP2[DP2['type'].str.contains('독')]
DPpoison
# Out:
#       name     type  height    weight    BMI
# num
# 1     이상해씨    풀 / 독  0.71 m    6.9 kg  13.69
# 2     이상해풀    풀 / 독  0.99 m   13.0 kg  13.26
# 3     이상해꽃    풀 / 독  2.01 m  100.0 kg  24.75
# 13     뿔충이   벌레 / 독  0.30 m    3.2 kg  35.56
# 14     딱충이   벌레 / 독  0.61 m   10.0 kg  26.87
# 15     독침붕   벌레 / 독  0.99 m   29.5 kg  30.10
# 23      아보        독  2.01 m    6.9 kg   1.71
# 24     아보크        독  3.51 m   65.0 kg   5.28
# 29    니드런♀        독  0.41 m    7.0 kg  41.64
# 30    니드리나        독  0.79 m   20.0 kg  32.05
# 31     니드퀸    독 / 땅  1.30 m   60.0 kg  35.50
# 32    니드런♂        독  0.51 m    9.0 kg  34.60
# 33    니드리노        독  0.89 m   19.5 kg  24.62
# 34     니드킹    독 / 땅  1.40 m   62.0 kg  31.63
# 41      주뱃   독 / 비행  0.79 m    7.5 kg  12.02
# 42      골뱃   독 / 비행  1.60 m   55.0 kg  21.48
# 43     뚜벅쵸    풀 / 독  0.51 m    5.4 kg  20.76
# 44     냄새꼬    풀 / 독  0.79 m    8.6 kg  13.78
# 45   라플레시아    풀 / 독  1.19 m   18.6 kg  13.13
# 48      콘팡   벌레 / 독  0.99 m   30.0 kg  30.61
# ...

# %%
DPwater=DP2[DP2['type'].str.contains('물')]
DPwater
# Out:
#      name     type  height    weight    BMI
# num
# 7     꼬부기        물  0.51 m    9.0 kg  34.60
# 8    어니부기        물  0.99 m   22.5 kg  22.96
# 9     거북왕        물  1.60 m   85.5 kg  33.40
# 54   고라파덕        물  0.79 m   19.6 kg  31.41
# 55     골덕        물  1.70 m   76.6 kg  26.51
# 60    발챙이        물  0.61 m   12.4 kg  33.32
# 61   슈륙챙이        물  0.99 m   20.0 kg  20.41
# 62    강챙이   물 / 격투  1.30 m   54.0 kg  31.95
# 72    왕눈해    물 / 독  0.89 m   45.5 kg  57.44
# 73    독파리    물 / 독  1.60 m   55.0 kg  21.48
# 79     야돈  물 / 에스퍼  1.19 m   36.0 kg  25.42
# 80    야도란  물 / 에스퍼  1.60 m   78.5 kg  30.66
# 86     쥬쥬        물  1.09 m   90.0 kg  75.75
# 87    쥬레곤   물 / 얼음  1.70 m  120.0 kg  41.52
# 90     셀러        물  0.30 m    4.0 kg  44.44
# 91    파르셀   물 / 얼음  1.50 m  132.5 kg  58.89
# 98     크랩        물  0.41 m    6.5 kg  38.67
# 99    킹크랩        물  1.30 m   60.0 kg  35.50
# 116   쏘드라        물  0.41 m    8.0 kg  47.59
# 117   시드라        물  1.19 m   25.0 kg  17.65
# ...

# %%
DProck=DP2[DP2['type'].str.contains('바위')]
DProck
# Out:
#      name     type  height    weight     BMI
# num
# 74    꼬마돌   바위 / 땅  0.41 m   20.0 kg  118.98
# 75    데구리   바위 / 땅  0.99 m  105.0 kg  107.13
# 76    딱구리   바위 / 땅  1.40 m  300.0 kg  153.06
# 95    롱스톤   바위 / 땅  8.79 m  210.0 kg    2.72
# 111   뿔카노   땅 / 바위  0.99 m  115.0 kg  117.33
# 112   코뿌리   땅 / 바위  1.91 m  120.0 kg   32.89
# 138  암나이트   바위 / 물  0.41 m    7.5 kg   44.62
# 139   암스타   바위 / 물  0.99 m   35.0 kg   35.71
# 140    투구   바위 / 물  0.51 m   11.5 kg   44.21
# 141  투구푸스   바위 / 물  1.30 m   40.5 kg   23.96
# 142   프테라  바위 / 비행  1.80 m   59.0 kg   18.21

# %%
DPground=DP2[DP2['type'].str.contains('땅')]
DPground
# Out:
#      name    type  height    weight     BMI
# num
# 27   모래두지       땅  0.61 m   12.0 kg   32.25
# 28     고지       땅  0.99 m   29.5 kg   30.10
# 31    니드퀸   독 / 땅  1.30 m   60.0 kg   35.50
# 34    니드킹   독 / 땅  1.40 m   62.0 kg   31.63
# 50    디그다       땅  0.20 m    0.8 kg   20.00
# 51   닥트리오       땅  0.71 m   33.3 kg   66.06
# 74    꼬마돌  바위 / 땅  0.41 m   20.0 kg  118.98
# 75    데구리  바위 / 땅  0.99 m  105.0 kg  107.13
# 76    딱구리  바위 / 땅  1.40 m  300.0 kg  153.06
# 95    롱스톤  바위 / 땅  8.79 m  210.0 kg    2.72
# 104   탕구리       땅  0.41 m    6.5 kg   38.67
# 105   텅구리       땅  0.99 m   45.0 kg   45.91
# 111   뿔카노  땅 / 바위  0.99 m  115.0 kg  117.33
# 112   코뿌리  땅 / 바위  1.91 m  120.0 kg   32.89

# %%
DPesper=DP2[DP2['type'].str.contains('에스퍼')]
DPesper
# Out:
#      name      type  height    weight    BMI
# num
# 63    캐이시       에스퍼  0.89 m   19.5 kg  24.62
# 64    윤겔라       에스퍼  1.30 m   56.5 kg  33.43
# 65     후딘       에스퍼  1.50 m   48.0 kg  21.33
# 79     야돈   물 / 에스퍼  1.19 m   36.0 kg  25.42
# 80    야도란   물 / 에스퍼  1.60 m   78.5 kg  30.66
# 96    슬리프       에스퍼  0.99 m   32.4 kg  33.06
# 97    슬리퍼       에스퍼  1.60 m   75.6 kg  29.53
# 102   아라리   풀 / 에스퍼  0.41 m    2.5 kg  14.87
# 103    나시   풀 / 에스퍼  2.01 m  120.0 kg  29.70
# 121  아쿠스타   물 / 에스퍼  1.09 m   80.0 kg  67.33
# 122   마임맨       에스퍼  1.30 m   54.5 kg  32.25
# 124   루주라  얼음 / 에스퍼  1.40 m   40.6 kg  20.71
# 150    뮤츠       에스퍼  2.01 m  122.0 kg  30.20
# 151     뮤       에스퍼  0.41 m    4.0 kg  23.80

# %%
DPice=DP2[DP2['type'].str.contains('얼음')]
DPice
# Out:
#      name      type  height    weight    BMI
# num
# 87    쥬레곤    물 / 얼음  1.70 m  120.0 kg  41.52
# 91    파르셀    물 / 얼음  1.50 m  132.5 kg  58.89
# 124   루주라  얼음 / 에스퍼  1.40 m   40.6 kg  20.71
# 131  라프라스    물 / 얼음  2.49 m  220.0 kg  35.48
# 144   프리져   얼음 / 비행  1.70 m   55.4 kg  19.17

# %%
DPghost=DP2[DP2['type'].str.contains('고스트')]
DPghost
# Out:
#      name     type  height   weight    BMI
# num
# 92    고오스  고스트 / 독  1.30 m   0.1 kg   0.06
# 93   고우스트  고스트 / 독  1.60 m   0.1 kg   0.04
# 94     팬텀  고스트 / 독  1.50 m  40.5 kg  18.00

# %%
DPfire=DP2[DP2['type'].str.contains('불')]
DPfire
# Out:
#      name     type  height    weight    BMI
# num
# 4     파이리       불꽃  0.61 m    8.5 kg  22.84
# 5     리자드       불꽃  1.09 m   19.0 kg  15.99
# 6     리자몽  불꽃 / 비행  1.70 m   90.5 kg  31.31
# 37   식스테일       불꽃  0.61 m    9.9 kg  26.61
# 38   나인테일       불꽃  1.09 m   19.9 kg  16.75
# 58     가디       불꽃  0.71 m   19.0 kg  37.69
# 59     윈디       불꽃  1.91 m  155.0 kg  42.49
# 77    포니타       불꽃  0.99 m   30.0 kg  30.61
# 78    날쌩마       불꽃  1.70 m   95.0 kg  32.87
# 126   마그마       불꽃  1.30 m   44.5 kg  26.33
# 136   부스터       불꽃  0.89 m   25.0 kg  31.56
# 146   파이어  불꽃 / 비행  2.01 m   60.0 kg  14.85

# %%
DPfly=DP2[DP2['type'].str.contains('비행')]
DPfly
# Out:
#       name      type  height    weight    BMI
# num
# 6      리자몽   불꽃 / 비행  1.70 m   90.5 kg  31.31
# 12     버터플   벌레 / 비행  1.09 m   32.0 kg  26.93
# 16      구구   노말 / 비행  0.30 m    1.8 kg  20.00
# 17      피죤   노말 / 비행  1.09 m   30.0 kg  25.25
# 18     피죤투   노말 / 비행  1.50 m   39.5 kg  17.56
# 21     깨비참   노말 / 비행  0.30 m    2.0 kg  22.22
# 22   깨비드릴조   노말 / 비행  1.19 m   38.0 kg  26.83
# 41      주뱃    독 / 비행  0.79 m    7.5 kg  12.02
# 42      골뱃    독 / 비행  1.60 m   55.0 kg  21.48
# 83     파오리   노말 / 비행  0.79 m   15.0 kg  24.03
# 84      두두   노말 / 비행  1.40 m   39.2 kg  20.00
# 85    두트리오   노말 / 비행  1.80 m   85.2 kg  26.30
# 123    스라크   벌레 / 비행  1.50 m   56.0 kg  24.89
# 130   갸라도스    물 / 비행  6.50 m  235.0 kg   5.56
# 142    프테라   바위 / 비행  1.80 m   59.0 kg  18.21
# 144    프리져   얼음 / 비행  1.70 m   55.4 kg  19.17
# 145     썬더   전기 / 비행  1.60 m   52.6 kg  20.55
# 146    파이어   불꽃 / 비행  2.01 m   60.0 kg  14.85
# 149    망나뇽  드래곤 / 비행  2.21 m  210.0 kg  43.00

# %%
DPnormal=DP2[DP2['type'].str.contains('노말')]
DPnormal
# Out:
#       name     type  height    weight     BMI
# num
# 16      구구  노말 / 비행  0.30 m    1.8 kg   20.00
# 17      피죤  노말 / 비행  1.09 m   30.0 kg   25.25
# 18     피죤투  노말 / 비행  1.50 m   39.5 kg   17.56
# 19      꼬렛       노말  0.30 m    3.5 kg   38.89
# 20     레트라       노말  0.71 m   18.5 kg   36.70
# 21     깨비참  노말 / 비행  0.30 m    2.0 kg   22.22
# 22   깨비드릴조  노말 / 비행  1.19 m   38.0 kg   26.83
# 35      삐삐       노말  0.61 m    7.5 kg   20.16
# 36      픽시       노말  1.30 m   40.0 kg   23.67
# 39      푸린       노말  0.51 m    5.5 kg   21.15
# 40     푸크린       노말  0.99 m   12.0 kg   12.24
# 52      나옹       노말  0.41 m    4.2 kg   24.99
# 53    페르시온       노말  0.99 m   32.0 kg   32.65
# 83     파오리  노말 / 비행  0.79 m   15.0 kg   24.03
# 84      두두  노말 / 비행  1.40 m   39.2 kg   20.00
# 85    두트리오  노말 / 비행  1.80 m   85.2 kg   26.30
# 108    내루미       노말  1.19 m   65.5 kg   46.25
# 113     럭키       노말  1.09 m   34.6 kg   29.12
# 115     캥카       노말  2.21 m   80.0 kg   16.38
# ...

# %%
DPbug=DP2[DP2['type'].str.contains('벌레')]
DPbug
# Out:
#      name     type  height   weight    BMI
# num
# 10    캐터피       벌레  0.30 m   2.9 kg  32.22
# 11    단데기       벌레  0.71 m   9.9 kg  19.64
# 12    버터플  벌레 / 비행  1.09 m  32.0 kg  26.93
# 13    뿔충이   벌레 / 독  0.30 m   3.2 kg  35.56
# 14    딱충이   벌레 / 독  0.61 m  10.0 kg  26.87
# 15    독침붕   벌레 / 독  0.99 m  29.5 kg  30.10
# 46    파라스   벌레 / 풀  0.30 m   5.4 kg  60.00
# 47   파라섹트   벌레 / 풀  0.99 m  29.5 kg  30.10
# 48     콘팡   벌레 / 독  0.99 m  30.0 kg  30.61
# 49    도나리   벌레 / 독  1.50 m  12.5 kg   5.56
# 123   스라크  벌레 / 비행  1.50 m  56.0 kg  24.89
# 127  쁘사이저       벌레  1.50 m  55.0 kg  24.44

# %%
DP2['type'].unique()
# Out:
# array(['풀 / 독', '불꽃', '불꽃 / 비행', '물', '벌레', '벌레 / 비행', '벌레 / 독',
#        '노말 / 비행', '노말', '독', '전기', '땅', '독 / 땅', '독 / 비행', '벌레 / 풀', '격투',
#        '물 / 격투', '에스퍼', '물 / 독', '바위 / 땅', '물 / 에스퍼', '물 / 얼음', '고스트 / 독',
#        '풀 / 에스퍼', '땅 / 바위', '풀', '얼음 / 에스퍼', '물 / 비행', '바위 / 물',
#        '바위 / 비행', '얼음 / 비행', '전기 / 비행', '드래곤', '드래곤 / 비행'], dtype=object)

# %%
DPdragon=DP2[DP2['type'].str.contains('드래곤')]
DPdragon
# Out:
#     name      type  height    weight    BMI
# num
# 147   미뇽       드래곤  1.80 m    3.3 kg   1.02
# 148   신뇽       드래곤  3.99 m   16.5 kg   1.04
# 149  망나뇽  드래곤 / 비행  2.21 m  210.0 kg  43.00

# %%
DPthun=DP2[DP2['type'].str.contains('전기')]
DPthun
# Out:
#      name     type  height   weight    BMI
# num
# 25    피카츄       전기  0.41 m   6.0 kg  35.69
# 26    라이츄       전기  0.79 m  30.0 kg  48.07
# 81     코일       전기  0.30 m   6.0 kg  66.67
# 82   레어코일       전기  0.99 m  60.0 kg  61.22
# 100  찌리리공       전기  0.51 m  10.4 kg  39.98
# 101    붐볼       전기  1.19 m  66.6 kg  47.03
# 125   에레브       전기  1.09 m  30.0 kg  25.25
# 135  쥬피썬더       전기  0.79 m  24.5 kg  39.26
# 145    썬더  전기 / 비행  1.60 m  52.6 kg  20.55

# %%
DPbatt=DP2[DP2['type'].str.contains('격투')]
DPbatt
# Out:
#      name    type  height    weight     BMI
# num
# 56     망키      격투  0.51 m   28.0 kg  107.65
# 57    성원숭      격투  0.99 m   32.0 kg   32.65
# 62    강챙이  물 / 격투  1.30 m   54.0 kg   31.95
# 66    알통몬      격투  0.79 m   19.5 kg   31.24
# 67    근육몬      격투  1.50 m   70.5 kg   31.33
# 68    괴력몬      격투  1.60 m  130.0 kg   50.78
# 106  시라소몬      격투  1.50 m   49.8 kg   22.13
# 107   홍수몬      격투  1.40 m   50.2 kg   25.61

# %%
typeSR=[[DPbatt,'격투','#C03028'],
        [DPbug,'벌레','#A8B820'],
        [DPdragon,'드래곤','#7038F8'],
        [DPesper,'에스퍼','#F85888'],
        [DPfire,'불꽃','#F08030'],
        [DPfly,'비행','#A890F0'],
        [DPghost,'고스트',"#705898"],
        [DPgrass,'풀','#78C850'],
        [DPground,'땅','#E0C068'],
        [DPice,'얼음','#98D8D8'],
        [DPnormal,'노말','#A8A878'],
        [DPpoison,'독','#A040A0'],
        [DProck,'바위','#B8A038'],
        [DPthun,'전기','#F8D030'],
        [DPwater,'물','#6890F0']]

# %%
len(typeSR)
# Out:
# 15

# %%
typeSR[0][1]
# Out:
# '격투'

# %%
y=DP2['BMI'].sort_values()
y
# Out:
# num
# 93       0.04
# 92       0.06
# 147      1.02
# 148      1.04
# 23       1.71
#         ...
# 75     107.13
# 56     107.65
# 111    117.33
# 74     118.98
# 76     153.06
# Name: BMI, Length: 151, dtype: float64

# %%
x=np.linspace(0, 100, len(DP2['BMI']))
x
# Out:
# array([  0.        ,   0.66666667,   1.33333333,   2.        ,
#          2.66666667,   3.33333333,   4.        ,   4.66666667,
#          5.33333333,   6.        ,   6.66666667,   7.33333333,
#          8.        ,   8.66666667,   9.33333333,  10.        ,
#         10.66666667,  11.33333333,  12.        ,  12.66666667,
#         13.33333333,  14.        ,  14.66666667,  15.33333333,
#         16.        ,  16.66666667,  17.33333333,  18.        ,
#         18.66666667,  19.33333333,  20.        ,  20.66666667,
#         21.33333333,  22.        ,  22.66666667,  23.33333333,
#         24.        ,  24.66666667,  25.33333333,  26.        ,
#         26.66666667,  27.33333333,  28.        ,  28.66666667,
#         29.33333333,  30.        ,  30.66666667,  31.33333333,
#         32.        ,  32.66666667,  33.33333333,  34.        ,
#         34.66666667,  35.33333333,  36.        ,  36.66666667,
#         37.33333333,  38.        ,  38.66666667,  39.33333333,
# ...

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 100, len(DP2['BMI']))
y=DP2['BMI'].sort_values()
plt.bar(x, y, label='전체',color='.75')
for types in typeSR:
    x = np.linspace(0, 100, len(types[0]['BMI']))
    y = types[0]['BMI'].sort_values()
    if types[1] =='땅':
        plt.annotate('데구리',fontsize='x-large', xy = (67,112),
        xytext = (40,140),
        arrowprops={'facecolor':'black'})
    plt.plot(x, y, label=f'{types[1]}', color=types[2])
plt.ylabel('BMI\n',va='top',fontsize='x-large',rotation=0)
plt.xticks(color='w')
plt.legend(fontsize='large')
plt.title('[타입별 BMI 비교-선]',fontsize='xx-large')
plt.show()

# %%
DProck.sort_values('BMI',ascending=False).head()
# Out:
#      name    type  height    weight     BMI
# num
# 76    딱구리  바위 / 땅  1.40 m  300.0 kg  153.06
# 74    꼬마돌  바위 / 땅  0.41 m   20.0 kg  118.98
# 111   뿔카노  땅 / 바위  0.99 m  115.0 kg  117.33
# 75    데구리  바위 / 땅  0.99 m  105.0 kg  107.13
# 138  암나이트  바위 / 물  0.41 m    7.5 kg   44.62

# %%
DPground.sort_values('BMI',ascending=False).head()
# Out:
#      name    type  height    weight     BMI
# num
# 76    딱구리  바위 / 땅  1.40 m  300.0 kg  153.06
# 74    꼬마돌  바위 / 땅  0.41 m   20.0 kg  118.98
# 111   뿔카노  땅 / 바위  0.99 m  115.0 kg  117.33
# 75    데구리  바위 / 땅  0.99 m  105.0 kg  107.13
# 51   닥트리오       땅  0.71 m   33.3 kg   66.06

# %%
DP2.sort_values('BMI').head()
# Out:
#      name     type  height   weight   BMI
# num
# 93   고우스트  고스트 / 독  1.60 m   0.1 kg  0.04
# 92    고오스  고스트 / 독  1.30 m   0.1 kg  0.06
# 147    미뇽      드래곤  1.80 m   3.3 kg  1.02
# 148    신뇽      드래곤  3.99 m  16.5 kg  1.04
# 23     아보        독  2.01 m   6.9 kg  1.71

# %%
listcol=[]
fig, ax = plt.subplots()
listype=[]
listnum=[]
for a in range(15):
    listype.append(typeSR[a][1])
    listnum.append(len(typeSR[a][0]))
    listcol.append(typeSR[a][2])
labels = listype
sizes = listnum
ax.pie(sizes, labels=labels, autopct='%1.1f%%',colors=listcol)
plt.show()

# %%
plt.scatter(DP2['type'],DP2['BMI'])
plt.ylabel('BMI')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 100, len(DP2['BMI']))
y=DP2['BMI'].sort_values()
plt.bar(x, y, label='전체',color='.75')
for types in typeSR:
    x = np.linspace(0, 100, len(types[0]['BMI']))
    y = types[0]['BMI'].sort_values()
    if types[1] =='땅':
        plt.annotate('데구리',fontsize='x-large', xy = (67,112),
        xytext = (40,140),
        arrowprops={'facecolor':'black'})
    if types[1] =='고스트':
        plt.annotate('고오스',fontsize='x-large', xy = (50,1),
        xytext = (40,80),
        arrowprops={'facecolor':'black','arrowstyle':'->'})
    plt.scatter(x, y, label=f'{types[1]}', color=types[2])
plt.ylabel('BMI\n',va='top',fontsize='x-large',rotation=0)
plt.xticks(color='w')
plt.legend(fontsize='large')
plt.title('[타입별 BMI 비교-점]',fontsize='xx-large')
plt.show()

# %%
DPall=pd.read_csv('../DATA/pokemondata.csv')
DPall
# Out:
#       Unnamed: 0     #                      Name            Type  Total   HP  \
# 0              0     1                 Bulbasaur   Grass  Poison    318   45
# 1              1     2                   Ivysaur   Grass  Poison    405   60
# 2              2     3                  Venusaur   Grass  Poison    525   80
# 3              3     3   Venusaur  Mega Venusaur   Grass  Poison    625   80
# 4              4     4                Charmander            Fire    309   39
# ...          ...   ...                       ...             ...    ...  ...
# 1210        1210  1023                Iron Crown  Steel  Psychic    590   90
# 1211        1211  1024    Terapagos  Normal Form          Normal    450   90
# 1212        1212  1024  Terapagos  Terastal Form          Normal    600   95
# 1213        1213  1024   Terapagos  Stellar Form          Normal    700  160
# 1214        1214  1025                 Pecharunt   Poison  Ghost    600   88
#
# ...

# %%
DPall2=DPall[DPall['#']<=1008].drop_duplicates(subset=['#'])
DPall2
# Out:
#       Unnamed: 0     #          Name              Type  Total   HP  Attack  \
# 0              0     1     Bulbasaur     Grass  Poison    318   45      49
# 1              1     2       Ivysaur     Grass  Poison    405   60      62
# 2              2     3      Venusaur     Grass  Poison    525   80      82
# 4              4     4    Charmander              Fire    309   39      52
# 5              5     5    Charmeleon              Fire    405   58      64
# ...          ...   ...           ...               ...    ...  ...     ...
# 1188        1188  1004        Chi-Yu        Dark  Fire    570   55      80
# 1189        1189  1005  Roaring Moon      Dragon  Dark    590  105     139
# 1190        1190  1006  Iron Valiant   Fairy  Fighting    590   74     130
# 1191        1191  1007      Koraidon  Fighting  Dragon    670  100     135
# 1192        1192  1008      Miraidon  Electric  Dragon    670  100      85
#
#       Defense  Sp. Atk  Sp. Def  Speed
# ...

# %%
DPgo=DPall[DPall['#']<=151].drop_duplicates(subset=['#'])
DPgo
# Out:
#      Unnamed: 0    #        Name            Type  Total   HP  Attack  Defense  \
# 0             0    1   Bulbasaur   Grass  Poison    318   45      49       49
# 1             1    2     Ivysaur   Grass  Poison    405   60      62       63
# 2             2    3    Venusaur   Grass  Poison    525   80      82       83
# 4             4    4  Charmander            Fire    309   39      52       43
# 5             5    5  Charmeleon            Fire    405   58      64       58
# ..          ...  ...         ...             ...    ...  ...     ...      ...
# 197         197  147     Dratini          Dragon    300   41      64       45
# 198         198  148   Dragonair          Dragon    420   61      84       65
# 199         199  149   Dragonite  Dragon  Flying    600   91     134       95
# 200         200  150      Mewtwo         Psychic    680  106     110       90
# 203         203  151         Mew         Psychic    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed
# ...

# %%
DPgo=DPgo.set_index('#')

# %%
DPdata=DPgo[DPgo.columns[3:]]
DPdata
# Out:
#      Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1      318   45      49       49       65       65     45
# 2      405   60      62       63       80       80     60
# 3      525   80      82       83      100      100     80
# 4      309   39      52       43       60       50     65
# 5      405   58      64       58       80       65     80
# ..     ...  ...     ...      ...      ...      ...    ...
# 147    300   41      64       45       50       50     50
# 148    420   61      84       65       70       70     70
# 149    600   91     134       95      100      100     80
# 150    680  106     110       90      154       90    130
# 151    600  100     100      100      100      100    100
#
# [151 rows x 7 columns]

# %%
pd.concat([DP1,DPdata],axis=1)
# Out:
#      name      type  height    weight           candy    egg  \
# 1    이상해씨     풀 / 독  0.71 m    6.9 kg      25 이상해씨 캔디   2 km
# 2    이상해풀     풀 / 독  0.99 m   13.0 kg     100 이상해씨 캔디   None
# 3    이상해꽃     풀 / 독  2.01 m  100.0 kg              없음   None
# 4     파이리        불꽃  0.61 m    8.5 kg       25 파이리 캔디   2 km
# 5     리자드        불꽃  1.09 m   19.0 kg      100 파이리 캔디   None
# ..    ...       ...     ...       ...             ...    ...
# 147    미뇽       드래곤  1.80 m    3.3 kg        25 미뇽 캔디  10 km
# 148    신뇽       드래곤  3.99 m   16.5 kg  100 Dratini 캔디   None
# 149   망나뇽  드래곤 / 비행  2.21 m  210.0 kg              없음   None
# 150    뮤츠       에스퍼  2.01 m  122.0 kg              없음   None
# 151     뮤       에스퍼  0.41 m    4.0 kg              없음   None
#
#                     multipliers          weaknesses  \
# 1                          1.58   [불꽃, 얼음, 비행, 에스퍼]
# 2                    [1.2, 1.6]   [불꽃, 얼음, 비행, 에스퍼]
# 3                          None   [불꽃, 얼음, 비행, 에스퍼]
# ...

# %%
file1='../DATA/Pokemon Database.csv'
DPreal=pd.read_csv(file1)
DPreal
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name     Classification  \
# 0              1               1     "Bulbasaur"     "Seed Pokémon"
# 1              2               2       "Ivysaur"     "Seed Pokémon"
# 2              3               3      "Venusaur"     "Seed Pokémon"
# 3              4               3      "Venusaur"     "Seed Pokémon"
# 4           1526               3      "Venusaur"     "Seed Pokémon"
# ...          ...             ...             ...                ...
# 1230        1685            1004        "Chi-Yu"  "Ruinous Pokémon"
# 1231        1742            1005  "Roaring Moon"  "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"  "Paradox Pokémon"
# 1233        1647            1007      "Koraidon"  "Paradox Pokémon"
# 1234        1648            1008      "Miraidon"  "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 0                    NaN                  NaN              NaN
# ...

# %%
DPreal.columns
# Out:
# Index(['Pokemon Id', 'Pokedex Number', 'Pokemon Name', 'Classification',
#        'Alternate Form Name', 'Original Pokemon ID', 'Legendary Type',
#        'Pokemon Height', 'Pokemon Weight', 'Primary Type', 'Secondary Type',
#        'Primary Ability', 'Primary Ability Description', 'Secondary Ability',
#        'Secondary Ability Description', 'Hidden Ability',
#        'Hidden Ability Description', 'Special Event Ability',
#        'Special Event Ability Description', 'Male Ratio', 'Female Ratio',
#        'Base Happiness', 'Game(s) of Origin', 'Health Stat', 'Attack Stat',
#        'Defense Stat', 'Special Attack Stat', 'Special Defense Stat',
#        'Speed Stat', 'Base Stat Total', 'Health EV', 'Attack EV', 'Defense EV',
#        'Special Attack EV', 'Special Defense EV', 'Speed EV', 'EV Yield Total',
#        'Catch Rate', 'Experience Growth', 'Experience Growth Total',
#        'Primary Egg Group', 'Secondary Egg Group', 'Egg Cycle Count',
# ...

# %%
DPreal['Pokedex Number']
# Out:
# 0          1
# 1          2
# 2          3
# 3          3
# 4          3
#         ...
# 1230    1004
# 1231    1005
# 1232    1006
# 1233    1007
# 1234    1008
# Name: Pokedex Number, Length: 1235, dtype: int64

# %%
indrop=DPreal[DPreal['Alternate Form Name'].notna()].index
indrop
# Out:
# Index([   3,    4,    8,    9,   10,   14,   15,   19,   23,   27,
#        ...
#        1114, 1115, 1120, 1125, 1137, 1153, 1154, 1155, 1189, 1225],
#       dtype='int64', length=206)

# %%
DPrealall=DPreal.drop(indrop)
DPrealall
# Out:
#       Pokemon Id  Pokedex Number    Pokemon Name     Classification  \
# 0              1               1     "Bulbasaur"     "Seed Pokémon"
# 1              2               2       "Ivysaur"     "Seed Pokémon"
# 2              3               3      "Venusaur"     "Seed Pokémon"
# 5              5               4    "Charmander"   "Lizard Pokémon"
# 6              6               5    "Charmeleon"    "Flame Pokémon"
# ...          ...             ...             ...                ...
# 1230        1685            1004        "Chi-Yu"  "Ruinous Pokémon"
# 1231        1742            1005  "Roaring Moon"  "Paradox Pokémon"
# 1232        1749            1006  "Iron Valiant"  "Paradox Pokémon"
# 1233        1647            1007      "Koraidon"  "Paradox Pokémon"
# 1234        1648            1008      "Miraidon"  "Paradox Pokémon"
#
#      Alternate Form Name  Original Pokemon ID   Legendary Type  \
# 0                    NaN                  NaN              NaN
# ...

# %%
DPrealall=DPrealall[['Pokedex Number','Pokemon Name','Pokemon Height','Pokemon Weight','Primary Type','Secondary Type']]
DPrealall
# Out:
#       Pokedex Number    Pokemon Name  Pokemon Height  Pokemon Weight  \
# 0                  1     "Bulbasaur"             0.7             6.9
# 1                  2       "Ivysaur"             1.0            13.0
# 2                  3      "Venusaur"             2.0           100.0
# 5                  4    "Charmander"             0.6             8.5
# 6                  5    "Charmeleon"             1.1            19.0
# ...              ...             ...             ...             ...
# 1230            1004        "Chi-Yu"             0.4             4.9
# 1231            1005  "Roaring Moon"             2.0           380.0
# 1232            1006  "Iron Valiant"             1.4            35.0
# 1233            1007      "Koraidon"             2.5           303.0
# 1234            1008      "Miraidon"             3.5           240.0
#
#      Primary Type Secondary Type
# 0         "Grass"       "Poison"
# 1         "Grass"       "Poison"
# 2         "Grass"       "Poison"
# ...

# %%
DPrealall['Secondary Type'].unique()        # 18종류(nan값은 따로)
# Out:
# array(['"Poison"', nan, '"Flying"', '"Ground"', '"Fairy"', '"Grass"',
#        '"Fighting"', '"Psychic"', '"Steel"', '"Ice"', '"Rock"', '"Water"',
#        '"Electric"', '"Fire"', '"Dragon"', '"Dark"', '"Ghost"', '"Bug"',
#        '"Normal"'], dtype=object)

# %%
DPrealall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1029 entries, 0 to 1234
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pokedex Number  1029 non-null   int64
#  1   Pokemon Name    1029 non-null   object
#  2   Pokemon Height  1029 non-null   float64
#  3   Pokemon Weight  1029 non-null   float64
#  4   Primary Type    1029 non-null   object
#  5   Secondary Type  522 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 56.3+ KB

# %%
BmSr=round((DPrealall['Pokemon Weight']/DPrealall['Pokemon Height']**2),2)
DPrealall['BMI']=BmSr
# Out:
# C:\Users\KDP-23\AppData\Local\Temp\ipykernel_15152\943753586.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DPrealall['BMI']=BmSr

# %%
DPrealall
# Out:
#       Pokedex Number    Pokemon Name  Pokemon Height  Pokemon Weight  \
# 0                  1     "Bulbasaur"             0.7             6.9
# 1                  2       "Ivysaur"             1.0            13.0
# 2                  3      "Venusaur"             2.0           100.0
# 5                  4    "Charmander"             0.6             8.5
# 6                  5    "Charmeleon"             1.1            19.0
# ...              ...             ...             ...             ...
# 1230            1004        "Chi-Yu"             0.4             4.9
# 1231            1005  "Roaring Moon"             2.0           380.0
# 1232            1006  "Iron Valiant"             1.4            35.0
# 1233            1007      "Koraidon"             2.5           303.0
# 1234            1008      "Miraidon"             3.5           240.0
#
#      Primary Type Secondary Type    BMI
# 0         "Grass"       "Poison"  14.08
# 1         "Grass"       "Poison"  13.00
# ...

# %%
DPrealall.sort_values(by='BMI',ascending=False)
# Out:
#       Pokedex Number Pokemon Name  Pokemon Height  Pokemon Weight  \
# 971              790    "Cosmoem"             0.1           999.9
# 954              774     "Minior"             0.3            40.0
# 398              304       "Aron"             0.4            60.0
# 786              632     "Durant"             0.3            33.0
# 473              366   "Clamperl"             0.4            52.5
# ...              ...          ...             ...             ...
# 220              148  "Dragonair"             4.0            16.5
# 219              147    "Dratini"             1.8             3.3
# 1067             864    "Cursola"             1.0             0.4
# 136               92     "Gastly"             1.3             0.1
# 137               93    "Haunter"             1.6             0.1
#
#      Primary Type Secondary Type       BMI
# 971     "Psychic"            NaN  99990.00
# 954        "Rock"       "Flying"    444.44
# ...

# %%
firSR=DPrealall['Primary Type'].str.contains('"Grass"')
firSR
# Out:
# 0        True
# 1        True
# 2        True
# 5       False
# 6       False
#         ...
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# Name: Primary Type, Length: 1029, dtype: bool

# %%
secSR=DPrealall['Secondary Type'].str.contains('"Grass"')
secSR
# Out:
# 0       False
# 1       False
# 2       False
# 5         NaN
# 6         NaN
#         ...
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# Name: Secondary Type, Length: 1029, dtype: object

# %%
DPrealall[firSR | secSR]
# Out:
#       Pokedex Number    Pokemon Name  Pokemon Height  Pokemon Weight  \
# 0                  1     "Bulbasaur"             0.7             6.9
# 1                  2       "Ivysaur"             1.0            13.0
# 2                  3      "Venusaur"             2.0           100.0
# 63                43        "Oddish"             0.5             5.4
# 64                44         "Gloom"             0.8             8.6
# ...              ...             ...             ...             ...
# 1173             949    "Toedscruel"             1.9            58.0
# 1175             951      "Capsakid"             0.3             3.0
# 1176             952    "Scovillain"             0.9            15.0
# 1211             986  "Brute Bonnet"             1.2            21.0
# 1227            1001      "Wo-Chien"             1.5            74.2
#
#      Primary Type Secondary Type    BMI
# 0         "Grass"       "Poison"  14.08
# 1         "Grass"       "Poison"  13.00
# ...

# %%
def maketype2(t):
    firSR=DPrealall['Primary Type'].str.contains(t)
    secSR=DPrealall['Secondary Type'].str.contains(t)
    return DPrealall[firSR | secSR]

# %%
DPgrass2=maketype2('"Grass"')
DPbatt2=maketype2('"Fighting"')
DPbug2=maketype2('"Bug"')
DPdragon2=maketype2('"Dragon"')
DPesper2=maketype2('"Psychic"')
DPfire2=maketype2('"Fire"')
DPfly2=maketype2('"Flying"')
DPghost2=maketype2('"Ghost"')
DPground2=maketype2('"Ground"')
DPice2=maketype2('"Ice"')
DPnormal2=maketype2('"Normal"')
DPpoison2=maketype2('"Poison"')
DProck2=maketype2('"Rock"')
DPthun2=maketype2('"Electric"')
DPwater2=maketype2('"Water"')
DPdark2=maketype2('"Dark"')
DPfairy2=maketype2('"Fairy"')
DPsteel2=maketype2('"Steel"')

# %%
DPrealall['Primary Type'].unique()          #18종류
# Out:
# array(['"Grass"', '"Fire"', '"Water"', '"Bug"', '"Normal"', '"Poison"',
#        '"Electric"', '"Ground"', '"Fairy"', '"Fighting"', '"Psychic"',
#        '"Rock"', '"Ghost"', '"Ice"', '"Dragon"', '"Dark"', '"Steel"',
#        '"Flying"'], dtype=object)

# %%
typeSR2=[[DPbatt2,'격투','#C03028'],
        [DPbug2,'벌레','#A8B820'],
        [DPdragon2,'드래곤','#7038F8'],
        [DPesper2,'에스퍼','#F85888'],
        [DPfire2,'불꽃','#F08030'],
        [DPfly2,'비행','#A890F0'],
        [DPghost2,'고스트',"#705898"],
        [DPgrass2,'풀','#78C850'],
        [DPground2,'땅','#E0C068'],
        [DPice2,'얼음','#98D8D8'],
        [DPnormal2,'노말','#A8A878'],
        [DPpoison2,'독','#A040A0'],
        [DProck2,'바위','#B8A038'],
        [DPthun2,'전기','#F8D030'],
        [DPwater2,'물','#6890F0'],
        [DPdark2,'악','#705848'],
        [DPfairy2,'페어리','#EE99AC'],
        [DPsteel2,'강철','#787887']]

# %%
DPesper2
# Out:
#       Pokedex Number   Pokemon Name  Pokemon Height  Pokemon Weight  \
# 91                63         "Abra"             0.9            19.5
# 92                64      "Kadabra"             1.3            56.5
# 93                65     "Alakazam"             1.5            48.0
# 94                65     "Alakazam"             1.5            48.0
# 117               79     "Slowpoke"             1.2            36.0
# ...              ...            ...             ...             ...
# 1179             955      "Flittle"             0.2             1.5
# 1180             956     "Espathra"             1.9            90.0
# 1201             976       "Veluza"             2.5            90.0
# 1206             981    "Farigiraf"             3.2           160.0
# 1210             985  "Scream Tail"             1.2             8.0
#
#      Primary Type Secondary Type    BMI
# 91      "Psychic"            NaN  24.07
# 92      "Psychic"            NaN  33.43
# ...

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 100, len(DPrealall['BMI']))
y = DPrealall['BMI'].sort_values()
plt.bar(x, y, label='전체',color='.75')
for types in typeSR2:
    x = np.linspace(0, 100, len(types[0]['BMI']))
    y = types[0]['BMI'].sort_values()
    if types[1] =='땅':
        plt.annotate('데구리',fontsize='x-large', xy = (67,112),
        xytext = (40,140),
        arrowprops={'facecolor':'black'})
    plt.plot(x, y, label=f'{types[1]}', color=types[2])
plt.ylabel('BMI\n',va='top',fontsize='x-large',rotation=0)
plt.xticks(color='w')
plt.legend(fontsize='large')
plt.title('[타입별 BMI 비교-선]',fontsize='xx-large')
plt.show()

# %%
DPesper3=DPesper2.sort_values(by='BMI').iloc[:-1]
typeSR3=[[DPbatt2,'격투','#C03028'],
        [DPbug2,'벌레','#A8B820'],
        [DPdragon2,'드래곤','#7038F8'],
        [DPesper3,'에스퍼','#F85888'],
        [DPfire2,'불꽃','#F08030'],
        [DPfly2,'비행','#A890F0'],
        [DPghost2,'고스트',"#705898"],
        [DPgrass2,'풀','#78C850'],
        [DPground2,'땅','#E0C068'],
        [DPice2,'얼음','#98D8D8'],
        [DPnormal2,'노말','#A8A878'],
        [DPpoison2,'독','#A040A0'],
        [DProck2,'바위','#B8A038'],
        [DPthun2,'전기','#F8D030'],
        [DPwater2,'물','#6890F0'],
        [DPdark2,'악','#705848'],
        [DPfairy2,'페어리','#EE99AC'],
        [DPsteel2,'강철','#787887']]

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 100, len(DPrealall['BMI'])-1)
y = DPrealall['BMI'].sort_values().iloc[:-1]
plt.bar(x, y, label='전체',color='.75')
for types in typeSR3:
    x = np.linspace(0, 100, len(types[0]['BMI']))
    y = types[0]['BMI'].sort_values()
    if types[1] =='땅':
        plt.annotate('데구리',fontsize='x-large', xy = (67,112),
        xytext = (40,140),
        arrowprops={'facecolor':'black'})
    plt.plot(x, y, label=f'{types[1]}', color=types[2])
plt.ylabel('BMI\n',va='top',fontsize='x-large',rotation=0)
plt.xticks(color='w')
plt.legend(fontsize='large')
plt.title('[타입별 BMI 비교-선]',fontsize='xx-large')
plt.show()

# %%
typeSR2[3][0]['BMI'].sort_values()
# Out:
# 1059        1.16
# 970         2.50
# 463         2.78
# 615         3.33
# 616         3.33
#           ...
# 484       214.84
# 558       242.00
# 1017      255.00
# 482       264.44
# 971     99990.00
# Name: BMI, Length: 103, dtype: float64

# %%
listcol=[]
fig, ax = plt.subplots(figsize=(10,10))
listype=[]
listnum=[]
for a in range(len(typeSR3)):
    listype.append(typeSR3[a][1])
    listnum.append(len(typeSR3[a][0]))
    listcol.append(typeSR3[a][2])
labels = listype
sizes = listnum
ax.pie(sizes, labels=labels, autopct='%1.1f%%',colors=listcol)
plt.show()

# %%
DPrealall.reset_index(drop=True,inplace=True)
DPall2.reset_index(drop=True,inplace=True)
DPrealall['Total']=DPall2['Total']
DPrealall
# Out:
# C:\Users\KDP-23\AppData\Local\Temp\ipykernel_15152\1656469255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DPrealall['Total']=DPall2['Total']
#       Pokedex Number    Pokemon Name  Pokemon Height  Pokemon Weight  \
# 0                  1     "Bulbasaur"             0.7             6.9
# 1                  2       "Ivysaur"             1.0            13.0
# 2                  3      "Venusaur"             2.0           100.0
# 3                  4    "Charmander"             0.6             8.5
# 4                  5    "Charmeleon"             1.1            19.0
# ...              ...             ...             ...             ...
# 1024            1004        "Chi-Yu"             0.4             4.9
# ...

# %%
DPrealall.corr(numeric_only=True)
# Out:
#                 Pokedex Number  Pokemon Height  Pokemon Weight       BMI  \
# Pokedex Number        1.000000        0.069304        0.129775  0.031458
# Pokemon Height        0.069304        1.000000        0.621964 -0.029975
# Pokemon Weight        0.129775        0.621964        1.000000  0.246202
# BMI                   0.031458       -0.029975        0.246202  1.000000
# Total                 0.170714       -0.002328       -0.037768 -0.034514
#
#                    Total
# Pokedex Number  0.170714
# Pokemon Height -0.002328
# Pokemon Weight -0.037768
# BMI            -0.034514
# Total           1.000000

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 100, len(DPrealall['BMI'])-1)
y = DPrealall['BMI'].sort_values().iloc[:-1]
plt.bar(x, y, label='전체',color='.75')
for types in typeSR3:
    x = np.linspace(0, 100, len(types[0]['BMI']))
    y = types[0]['BMI'].sort_values()
    if types[1] =='땅':
        plt.annotate('데구리',fontsize='x-large', xy = (70,107),
        xytext = (20,60),
        arrowprops={'facecolor':'black','arrowstyle':'->'})
    
    plt.plot(x, y, label=f'{types[1]}', color=types[2])
plt.ylim((0,110))
plt.ylabel('BMI\n',va='top',fontsize='x-large',rotation=0)
plt.xticks(color='w')
plt.legend(fontsize='large')
plt.title('[타입별 BMI 비교-선]',fontsize='xx-large')
plt.show()

# %%
DPghost2.sort_values('BMI')
# Out:
#       Pokedex Number  Pokemon Name  Pokemon Height  Pokemon Weight  \
# 137               93     "Haunter"             1.6             0.1
# 136               92      "Gastly"             1.3             0.1
# 1067             864     "Cursola"             1.0             0.4
# 1170             946    "Bramblin"             0.6             0.6
# 384              292    "Shedinja"             0.8             1.2
# ...              ...           ...             ...             ...
# 1196             971    "Greavard"             0.6            35.0
# 564              442   "Spiritomb"             1.0           108.0
# 1131             911  "Skeledirge"             1.6           326.5
# 950              770   "Palossand"             1.3           250.0
# 949              769   "Sandygast"             0.5            70.0
#
#      Primary Type Secondary Type     BMI
# 137       "Ghost"       "Poison"    0.04
# 136       "Ghost"       "Poison"    0.06
# ...

# %%
for a in typeSR3:
    print(a[0].corr(numeric_only=True))
# Out:
#                 Pokedex Number  Pokemon Height  Pokemon Weight       BMI
# Pokedex Number        1.000000        0.278393        0.255335  0.012482
# Pokemon Height        0.278393        1.000000        0.659465 -0.110496
# Pokemon Weight        0.255335        0.659465        1.000000  0.465325
# BMI                   0.012482       -0.110496        0.465325  1.000000
#                 Pokedex Number  Pokemon Height  Pokemon Weight       BMI
# Pokedex Number        1.000000        0.073128        0.123063  0.130636
# Pokemon Height        0.073128        1.000000        0.723308 -0.248145
# Pokemon Weight        0.123063        0.723308        1.000000  0.088349
# BMI                   0.130636       -0.248145        0.088349  1.000000
#                 Pokedex Number  Pokemon Height  Pokemon Weight       BMI
# Pokedex Number        1.000000        0.023063        0.089930  0.146648
# Pokemon Height        0.023063        1.000000        0.762029 -0.327795
# ...

# %%
plt.figure(figsize=(12,8))
x=[]
y=[]
c=[]
for types in typeSR3:
    y.append(types[0]['BMI'].sort_values())
    x.append(types[1])
    c.append(types[2])
bplot=plt.boxplot(y, vert=True, patch_artist=True, labels=x)
plt.title('[타입별 BMI 비교-박스]', fontsize='xx-large')
for patch, color in zip(bplot['boxes'],c):
    patch.set_facecolor(color)
plt.xlabel('타입별',fontsize='large')
plt.ylim(0,250)
plt.annotate('분포가 넓다',xytext=(5,200),xy=(4,150),arrowprops={'facecolor':'black','arrowstyle':'->'},fontsize='large')
plt.annotate('가볍다',xytext=(6,150),xy=(6,50),arrowprops={'facecolor':'b','edgecolor':'red','arrowstyle':'->'},fontsize='large')
plt.ylabel('BMI 지수',fontsize='large')
plt.show()
