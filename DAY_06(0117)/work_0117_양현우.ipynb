# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl                 # 패키지 관련
import matplotlib.font_manager as fm     # 패키지 리소스 즉 자원 중 폰트 관련 모듈

# %%
myFont=fm.FontProperties(fname='C:/Windows/Fonts/gulim.ttc').get_name()
mpl.rc('font',family=myFont)

# %%
file='../DATA/경기도행정구역경계.json'

# %%
gside=pd.read_json(file)
gside.tail()
# Out:
#                  type                                           features
# 39  FeatureCollection  {'type': 'Feature', 'properties': {'code': 310...
# 40  FeatureCollection  {'type': 'Feature', 'properties': {'code': 310...
# 41  FeatureCollection  {'type': 'Feature', 'properties': {'code': 310...
# 42  FeatureCollection  {'type': 'Feature', 'properties': {'code': 310...
# 43  FeatureCollection  {'type': 'Feature', 'properties': {'code': 310...

# %%
gside.loc[2]
# Out:
# type                                        FeatureCollection
# features    {'type': 'Feature', 'properties': {'code': 313...
# Name: 2, dtype: object

# %%
type(gside.loc[0])
# Out:
# pandas.core.series.Series

# %%
gside.loc[0,'type']
# Out:
# 'FeatureCollection'

# %%
ddang0=gside.loc[0,'features']
ddang0
# Out:
# {'type': 'Feature',
#  'properties': {'code': 31380,
#   'name': '양평군',
#   'name_eng': 'Yangpyeong-gun',
#   'base_year': 2013},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[127.56113535909492, 37.6256560539258],
#     [127.57290963929243, 37.61087369350498],
#     [127.56366973908277, 37.5842624297699],
#     [127.52226606559191, 37.5828628697518],
#     [127.50048767007603, 37.569036373178626],
#     [127.47687473909174, 37.574448241913856],
#     [127.47565866803647, 37.60512112601634],
#     [127.44699730711024, 37.644975847411644],
#     [127.4272349102434, 37.66284420898682],
#     [127.40156700708162, 37.64806970784708],
#     [127.3732642199939, 37.6453987554284],
#     [127.3542931884407, 37.6250006376975],
#     [127.34360057873045, 37.588997440929354],
#     [127.31002843450217, 37.53523876142835],
#     [127.30923294884336, 37.5135706079458],
#     [127.32809611134748, 37.53133849534739],
#     [127.3663244453597, 37.52716845880826],
# ...

# %%
DP1=pd.json_normalize(data=gside['features'])
DP1
# Out:
#        type  properties.code properties.name  properties.name_eng  \
# 0   Feature            31380             양평군       Yangpyeong-gun
# 1   Feature            31370             가평군         Gapyeong-gun
# 2   Feature            31350             연천군        Yeoncheon-gun
# 3   Feature            31280             여주시             Yeoju-si
# 4   Feature            31270             포천시            Pocheonsi
# 5   Feature            31260             양주시             Yangjusi
# 6   Feature            31250             광주시              Gwangju
# 7   Feature            31240             화성시           Hwaseongsi
# 8   Feature            31230             김포시             Gimpo-si
# 9   Feature            31220             안성시           Anseong-si
# 10  Feature            31210             이천시            Icheon-si
# 11  Feature            31200             파주시              Paju-si
# 12  Feature            31193          용인시수지구       Yonginsisujigu
# ...

# %%
DP1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  44 non-null     object
#  1   properties.code       44 non-null     int64
#  2   properties.name       44 non-null     object
#  3   properties.name_eng   44 non-null     object
#  4   properties.base_year  44 non-null     int64
#  5   geometry.type         44 non-null     object
#  6   geometry.coordinates  44 non-null     object
# dtypes: int64(2), object(5)
# memory usage:
#    [126.65235349062866, 37.22264393643188],
#    [126.62465751982253, 37.233811135502776],
#    [126.61085741500113, 37.260209230779175],
#    [126.59892279766748, 37.25959717398652],
#    [126.57228115154807, 37.277020701082655],
#    [126.61008573444688, 37.30616739414492]]],
#  [[[126.84283747134161, 37.360869895636554],
#    [126.82580289305967, 37.360321842249355],
#    [126.79105964941944, 37.33699094698096],
#    [126.76357575956314, 37.33864505297868],
# ...

# %%
pd.DataFrame(DP1.loc[0,'geometry.coordinates'])
# Out:
#                                        0   \
# 0  [127.56113535909492, 37.6256560539258]
#
#                                         1   \
# 0  [127.57290963929243, 37.61087369350498]
#
#                                        2   \
# 0  [127.56366973908277, 37.5842624297699]
#
#                                        3   \
# 0  [127.52226606559191, 37.5828628697518]
#
#                                          4   \
# 0  [127.50048767007603, 37.569036373178626]
#
#                                          5   \
# 0  [127.47687473909174, 37.574448241913856]
#
#                                         6   \
# 0  [127.47565866803647, 37.60512112601634]
#
#                                          7   \
# 0  [127.44699730711024, 37.644975847411644]
#
#                                        8   \
# 0  [127.4272349102434, 37.66284420898682]
#
#                                         9   ...  \
# 0  [127.40156700708162, 37.64806970784708]  ...
#
# ...

# %%
pd.DataFrame(DP1.loc[1,'geometry.coordinates'])
# Out:
#                                          0   \
# 0  [127.44780328408541, 38.048238751068475]
#
#                                         1   \
# 0  [127.42042182072485, 38.01200319871128]
#
#                                          2   \
# 0  [127.41516664705571, 37.995046525366845]
#
#                                         3   \
# 0  [127.39194666896421, 37.97992649728499]
#
#                                          4   \
# 0  [127.37828420492166, 37.958773972665476]
#
#                                         5   \
# 0  [127.3864253692493, 37.940789082655876]
#
#                                          6   \
# 0  [127.35796486335995, 37.918888706648104]
#
#                                        7   \
# 0  [127.33112989323685, 37.9192732427266]
#
#                                          8   \
# 0  [127.32585628843694, 37.870866578736496]
#
#                                         9   ...  \
# 0  [127.31427495278925, 37.86338279582678]  ...
#
# ...

# %%
pd.DataFrame(DP1.loc[3,'geometry.coordinates'])
# Out:
#                                         0   \
# 0  [127.40276739880215, 37.41856433413549]
#
#                                          1   \
# 0  [127.41955611640327, 37.386674887879835]
#
#                                        2   \
# 0  [127.44514756834636, 37.3842770721951]
#
#                                         3   \
# 0  [127.44459662819855, 37.35562085049101]
#
#                                         4   \
# 0  [127.47263652805968, 37.35869263849808]
#
#                                          5   \
# 0  [127.49167370715485, 37.339527598960764]
#
#                                          6   \
# 0  [127.51574229064994, 37.336561285567946]
#
#                                         7   \
# 0  [127.54853754663094, 37.29860192066929]
#
#                                         8   \
# 0  [127.53106721989582, 37.27115011578052]
#
#                                        9   ...  \
# 0  [127.5395160453677, 37.24379045683148]  ...
#
# ...

# %%
pd.DataFrame(DP1['geometry.coordinates'][0][0])
# Out:
#              0          1
# 0   127.561135  37.625656
# 1   127.572910  37.610874
# 2   127.563670  37.584262
# 3   127.522266  37.582863
# 4   127.500488  37.569036
# 5   127.476875  37.574448
# 6   127.475659  37.605121
# 7   127.446997  37.644976
# 8   127.427235  37.662844
# 9   127.401567  37.648070
# 10  127.373264  37.645399
# 11  127.354293  37.625001
# 12  127.343601  37.588997
# 13  127.310028  37.535239
# 14  127.309233  37.513571
# 15  127.328096  37.531338
# 16  127.366324  37.527168
# 17  127.382863  37.501475
# 18  127.390468  37.474134
# 19  127.374907  37.455073
# 20  127.391744  37.425648
# 21  127.402767  37.418564
# 22  127.425005  37.436700
# 23  127.481790  37.420844
# 24  127.510153  37.436996
# 25  127.525012  37.431920
# 26  127.539106  37.408493
# 27  127.605287  37.416970
# 28  127.637540  37.410656
# 29  127.649184  37.402043
# 30  127.669768  37.408844
# 31  127.710715  37.407366
# 32  127.703474  37.371054
# 33  127.761654  37.364219
# ...

# %%
x=pd.DataFrame(DP1['geometry.coordinates'][0][0])[0]
y=pd.DataFrame(DP1['geometry.coordinates'][0][0])[1]
plt.plot(x,y)
plt.show()

# %%
def findG(a):
    x=pd.DataFrame(DP1['geometry.coordinates'][a][0])[0]
    y=pd.DataFrame(DP1['geometry.coordinates'][a][0])[1]
    plt.plot(x,y)
    plt.show()

# %%
DP1['properties.name'][1]
# Out:
# '가평군'

# %%
for a in range(43):
    if DP1['geometry.type'][a] == 'Polygon':
        x=pd.DataFrame(DP1['geometry.coordinates'][a][0])[0]
        y=pd.DataFrame(DP1['geometry.coordinates'][a][0])[1]
        plt.title(DP1['properties.name'][a])
        plt.plot(x,y)
        plt.show()
    else:
        x1=pd.DataFrame(DP1['geometry.coordinates'][a][0][0])[0]
        y1=pd.DataFrame(DP1['geometry.coordinates'][a][0][0])[1]
        x2=pd.DataFrame(DP1['geometry.coordinates'][a][1][0])[0]
        y2=pd.DataFrame(DP1['geometry.coordinates'][a][1][0])[1]
        plt.title(DP1['properties.name'][a])
        plt.plot(x1,y1)
        plt.plot(x2,y2)
        plt.show()

# %%
for a in range(43):
    if DP1['geometry.type'][a] == 'Polygon':
        x=pd.DataFrame(DP1['geometry.coordinates'][a][0])[0]
        y=pd.DataFrame(DP1['geometry.coordinates'][a][0])[1]
        plt.title(DP1['properties.name'][a])
        plt.plot(x,y)

    else:
        x1=pd.DataFrame(DP1['geometry.coordinates'][a][0][0])[0]
        y1=pd.DataFrame(DP1['geometry.coordinates'][a][0][0])[1]
        x2=pd.DataFrame(DP1['geometry.coordinates'][a][1][0])[0]
        y2=pd.DataFrame(DP1['geometry.coordinates'][a][1][0])[1]
        plt.title(DP1['properties.name'][a])
        plt.plot(x1,y1)
        plt.plot(x2,y2)
plt.show()

# %%
x1=DP1['geometry.coordinates'][0][0][0]
y1=DP1['geometry.coordinates'][0][0][1]
y2=DP1['geometry.coordinates'][0][1][0]
y2=DP1['geometry.coordinates'][0][1][1]
listx1.append(x1)
listy1.append(y1)
plt.plot(listx,listy)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[104], line 3
#       1 x1=DP1['geometry.coordinates'][0][0][0]
#       2 y1=DP1['geometry.coordinates'][0][0][1]
# ----> 3 y2=DP1['geometry.coordinates'][0][1][0]
#       4 y2=DP1['geometry.coordinates'][0][1][1]
#       5 listx1.append(x1)
#
# IndexError: list index out of range

# %%
list2=[]
for a in range(43):
    if DP1['geometry.type'][a] == 'Polygon':
        x=pd.DataFrame(DP1['geometry.coordinates'][a][0])[0]
        y=pd.DataFrame(DP1['geometry.coordinates'][a][0])[1]
        list2.append([x,y])
list2
